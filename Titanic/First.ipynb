# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
testData = pd.read_csv('test.csv')
testData.set_index('PassengerId', inplace=True)
testData
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
# ...

# %%
testData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    418 non-null    int64
#  1   Name      418 non-null    object
#  2   Sex       418 non-null    object
#  3   Age       332 non-null    float64
#  4   SibSp     418 non-null    int64
#  5   Parch     418 non-null    int64
#  6   Ticket    418 non-null    object
#  7   Fare      417 non-null    float64
#  8   Cabin     91 non-null     object
#  9   Embarked  418 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB

# %%
testData.Age.isnull().sum()
# Out:
# np.int64(86)

# %%
traindata = pd.read_csv('train.csv')
traindata.set_index('PassengerId', inplace=True)
traindata
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
traindata.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
traindata.describe().T
# Out:
#           count       mean        std   min      25%      50%   75%       max
# Survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# Pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# Age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# SibSp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# Parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# Fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
traindata.plot()
# Out:
# <Axes: xlabel='PassengerId'>

# %%
traindata[['Pclass', 'Fare']].corr()
# Out:
#         Pclass    Fare
# Pclass  1.0000 -0.5495
# Fare   -0.5495  1.0000

# %%
traindata['Pclass'].corr(traindata['Fare'])
# Out:
# np.float64(-0.5494996199439081)

# %%
newTrain = traindata.select_dtypes(exclude='object')
newTrain
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare
# PassengerId
# 1                   0       3  22.0      1      0   7.2500
# 2                   1       1  38.0      1      0  71.2833
# 3                   1       3  26.0      0      0   7.9250
# 4                   1       1  35.0      1      0  53.1000
# 5                   0       3  35.0      0      0   8.0500
# ...               ...     ...   ...    ...    ...      ...
# 887                 0       2  27.0      0      0  13.0000
# 888                 1       1  19.0      0      0  30.0000
# 889                 0       3   NaN      1      2  23.4500
# 890                 1       1  26.0      0      0  30.0000
# 891                 0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
sns.heatmap(newTrain.corr(), annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
#plt.tight_layout()
plt.show()

# %%
col_with_null = traindata.isnull().sum().sort_values(ascending=False)
col_with_null.head(20)
# Out:
# Cabin       687
# Age         177
# Embarked      2
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# dtype: int64

# %%
#traindata=pd.get_dummies(traindata, columns=['Sex'])
del traindata['Embarked']

# %%
del traindata['Cabin']
traindata
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
age_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

traindata['Clean Age'] = age_pipeline.fit_transform(traindata[['Age']])
testData['Clean Age'] = age_pipeline.fit_transform(testData[['Age']])

# %%
traindata.info
# Out:
# <bound method DataFrame.info of              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...

# %%
traindata
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
testData
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
y = traindata['Survived']

# %%
features = ['Pclass', 'Sex', 'SibSp', 'Parch', 'Clean Age' ]
X = pd.get_dummies(traindata[features])

# %%
X_test = pd.get_dummies(testData[features])

# %%
print(len(predictions))
print(len(X_test.index))
# Out:
# 418
# 418

# %%
model = LogisticRegression(max_iter=200)
model.fit(X,y)
predictions = model.predict(X_test)
output = pd.DataFrame({
    'PassengerId': X_test.index,   # or df.index if you prefer
    'Survived': predictions
})
print(len(predictions))
print(len(X_test.index))
print("Done")
# Out:
# 418
# 418
# Done

# %%
output
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
traindata
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y, model.predict(X))
print(accuracy)
# Out:
# 0.7901234567901234

# %%
from sklearn.metrics import classification_report, confusion_matrix
train_predictions = model.predict(X)

print(confusion_matrix(y, train_predictions))
print(classification_report(y, train_predictions))
# Out:
# [[462  87]
#  [100 242]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       549
#            1       0.74      0.71      0.72       342
#
#     accuracy                           0.79       891
#    macro avg       0.78      0.77      0.78       891
# weighted avg       0.79      0.79      0.79       891

# %%
output.to_csv('submission.csv', index=False)
